# %% [markdown]
# <a href="https://colab.research.google.com/github/leijoha271182/ACT3_BACKINVENT_JWT/blob/main/LEIDY_JOHANNA_OCAMPO_ARROYAVE_EvidenciaAprendizaje03_DiplomadoICD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="left">
# <p><img alt="IUDigital" height="140px" src="https://www.iudigital.edu.co/Style%20Library/images/logo-escudo.png" align="left" hspace="10px" vspace="0px"></p></div>
# <div> </div>
# <div align="right">
# <p><img alt="Posgrado" height="140px" src="https://www.iudigital.edu.co/OfertaEducativa/PublishingImages/Paginas/Tecnologia-en-Desarrollo-de-Software/19072021_Tecnologia_Dllo_Software_1200px.jpg" align="right" hspace="10px" vspace="10px"></p></div>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <p>
# <h1> <b> Tarea 2 - Modelo de Clasificación </b> </h1>
# <hr size=10 noshade color="red">
# </p>

# %% [markdown]
# # **Evidencia de Aprendizaje 3**
#
# ## Modelo de Clasificación

# %%
#@markdown # Ingresar el nombre de los estudiantes
Estudiante_1 = "Diana Patricia Galeano Mesa" #@param {type:"string"}
Estudiante_2 = "Leidy Johanna Ocampo Arroyave" #@param {type:"string"}

# %% [markdown]
# # Descripción de la Evidencia de Aprendizaje
#
# Para llevar a cabo la presente actividad, se requiere presentar un documento en Google Colab donde se describa el procedimiento realizado para clasificar valores o categorías utilizando un modelo de clasificación no supervisado de Machine Learning. El documento de Google Colab debe incluir una introducción, el planteamiento del problema, una descripción detallada del procedimiento seguido y las conclusiones obtenidas. Además, se deben utilizar los datos de la tarea primera y segunda tarea y los de la primera tarea deben ser cargarlos desde GitHub. A partir de estos datos, se realizará una categorización o clasificación a una categoría. Asimismo, es necesario crear al menos tres gráficas que permitan visualizar información generalizada, incluyendo al menos una gráfica relacionada con los resultados obtenidos. También se debe realizar un análisis descriptivo de los resultados, utilizando métricas relevantes. Finalmente, se deben describir las métricas de validación utilizadas.

# %% [markdown]
# # Instrucciones iniciales
#
# *   ## Defina un modelo a utilizar
# *   ## Siga los pasos detallados en clase
# *   ## Cree un un clasificador, calcule los valores, almacénelos en una nueva columna.
# *   ## Calcule las métricas de aceptación para el modelo
# *   ## Describa los resultados.

# %% [markdown]
# # Instrucciones de la Evidencia de Aprendizaje:
#
# A partir de la información obtenida modifique el documento Google Colab cargado en el presente documento o modificado directamente de la tarea de Google Classroom.
#
# Describa el procedimiento realizado para crear el modelo de clasificación.
#
# *   El documento Google Colab debe contar con:
# *   Introducción
# *   Planteamiento del problema
# *   Descripción del valor a predecir.
# *   Crear el modelo de clasificación
# *   Dividir los datos en entrenamiento y prueba
# *   Predecir valores
# *   Calcular las métricas de aceptación
# *   Respuestas a Ruta Metodológica
# *   Conclusiones
# *   Cargar el documento con extensión ipynb

# %% [markdown]
# # Desarrollo de Ruta Metodológica
#
# Después de analizar la información extraída y transformada, responde a las siguientes preguntas:
#
# >*   ¿El valor o dato a clasificado está bien seleccionado?
# >*   ¿El Score o métricas del modelo se ajustan a la realidad?
# >*   ¿Los tiempos de predicción son cortos, medianos, largos?
# >*   ¿Qué observaciones tienes del modelo y de sus resultados?
#
# Codifica toda la solución en un Notebook de Google Colab explicando cada paso usando las celdas de texto y código que provee esta herramienta. Recuerda que para ingresar a Google Colab debes ingresar usando la cuenta institucional, ya que esta cuenta tiene vinculado un Google workspace.

# %% [markdown]
# ####**SOLUCIÓN**
#
# ---

# %% [markdown]
# <div align="left">
# <p><img alt="Ministerio de Transporte" height="50px" src= https://plc.mintransporte.gov.co/Portals/0/LogoMintransporteDoble.jpg?ver=2023-05-29-064645-627 align="left" hspace="10px" vspace="0px"></p></div>
#
# <div align ="center">
# ###**REGISTRO DE VIAJE MUNICIPAL***
#  <h2> <b> Ministerio de Transporte-Registro de tiempos logísticos de viaje municipal</b> </h1>
#  </div>
#
#
# ####**INTRODUCCIÓN**
# <div align ="justify">
# <p><br>El Ministerio de Transporte ha buscado realizar seguimiento al proceso de logística del transporte de carga, con el propósito de reconocer y controlar el movimiento de estos vehículos al interior del país y en cumplimiento normativo de regulación del servicio público.  Para llevar a cabo dicho control y vigilancia ha establecido algunos sistemas de información que han facilitado esta función como lo es el registro de Viaje Municipal por parte de las empresas de transporte, que permite conocer información sobre las condiciones y características de cada viaje, lugar pactado para cargue y descargue de mercancía, tiempos de desplazamiento, vehículo responsable, entre otros datos importantes.</br>
# <br>A partir de los datos recolectados por el Ministerio de Transporte, se pretende generar algunos pronósticos que permitan al Ministerio definir estrategias futuras en términos de políticas públicas que mejoren las condiciones de los transportadores, articular acciones con otras agencias del país como INVIAS, Ministeerio agropecuario, entre otros, con el propósito de mejorar condiciones de los transportadores y del transporte en general. </br>
#  </p>
#  </div>

# %% [markdown]
# ###**PLANTEAMIENTO DEL PROBLEMA**
# <div align ="justify">
# <p>El transporte de carga en Colombia es un factor fundamental de la economía, pues a través de este los productos son trasladados de forma eficiente entre los diferentes departamentos y municipios.  La movilización de los diferentes vehículos de carga, su control y vigilancia son responsabilidad del Ministerio de Transporte quien a través de diferentes sistemas de información y/o plataformas ha facilitado el conocimiento de las características de cada traslado y o flujo de los vehículos de carga.
#
# <br>Actualmente se cuenta con información que describe ciudades de salida y de destino, hora de viaje, tipo de carga, producto, tiempo de carga y descarga, sin embargo esta información marca un punto de partida importante para calcular la cantidad de productos, materiales y otros que se transportan por las carreteras del país, siendo esta información valiosa para reconocer las necesidades de vehículos, carreteras y mejoras a la infraestructura que deberán realizarse para garantizar el flujo vehicular en cinco o diez años.<br>
#
# <br>Se hace necesario mejorar la eficiencia logística con modelos predictivos que permitan cuantificar o proyectar las necesidades de carga del país y de esta manera establecer políticas de transporte que faciliten la movilización de productos, materiales entre otros que son de necesidad de la población colombiana</br>
#  </p>
#  </div>

# %% [markdown]
# ###**DESCRIPCIÓN DEL VALOR A PREDECIR**
# <div align ="justify">
# <p>Se pretende identificar y pronosticar el valor pagado por un viaje según el tiempo de viaje.</p>

# %% [markdown]
# ###**CREAR EL MODELO DE CLASIFICACIÓN (K-MEANS)**
#
# Revisemos los datos:
# [https://raw.githubusercontent.com/leijoha271182/Tiempos_logistica_cargue/1e2d8a12c02b91ebe749be3776d8fc3865f4100d/Data/Tiempos_Logisticos_vehiculos_de_carga_Trabajo.csv](https://raw.githubusercontent.com/leijoha271182/Tiempos_logistica_cargue/1e2d8a12c02b91ebe749be3776d8fc3865f4100d/Data/Tiempos_Logisticos_vehiculos_de_carga_Trabajo.csv)

# %%
import warnings
warnings.simplefilter("ignore")
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier #Binning
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler


ruta = 'https://raw.githubusercontent.com/leijoha271182/Tiempos_logistica_cargue/1e2d8a12c02b91ebe749be3776d8fc3865f4100d/Data/Tiempos_Logisticos_vehiculos_de_carga_Trabajo.csv'
df = pd.read_csv(ruta, sep=";")
df.dtypes
# Out:
# NATURALEZA                 object
# COD_PRODUCTO               object
# PRODUCTO                   object
# CANTIDAD                   object
# UNID_MEDIDA                object
# CODIGO_CARGUE               int64
# CARGUE                     object
# CODIGO_DESCARGUE            int64
# DESCARGUE                  object
# HORAS_VIAJE               float64
# HORAS_ESPERA_CARGUE       float64
# HORAS_CARGUE              float64
# HORAS_ESPERA_DESCARGUE    float64
# HORAS_DESCARGUE           float64
# VALOR_PACTADO             float64
# VALOR_PAGADO              float64
# CANTIDAD_REMESAS_VIAJE      int64
# EMPRESA_TRANSPORTE          int64
# PLACA                       int64
# CONDUCTOR                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['NATURALEZA', 'COD_PRODUCTO', 'PRODUCTO', 'CANTIDAD', 'UNID_MEDIDA',
#        'CODIGO_CARGUE', 'CARGUE', 'CODIGO_DESCARGUE', 'DESCARGUE',
#        'HORAS_VIAJE', 'HORAS_ESPERA_CARGUE', 'HORAS_CARGUE',
#        'HORAS_ESPERA_DESCARGUE', 'HORAS_DESCARGUE', 'VALOR_PACTADO',
#        'VALOR_PAGADO', 'CANTIDAD_REMESAS_VIAJE', 'EMPRESA_TRANSPORTE', 'PLACA',
#        'CONDUCTOR'],
#       dtype='object')

# %%
df.shape
# Out:
# (76456, 20)

# %%
print(df.describe(include='all'))
# Out:
#           NATURALEZA COD_PRODUCTO                 PRODUCTO CANTIDAD  \
# count          76287        76456                    76456    76456
# unique             6         1004                     1021    10550
# top     Carga Normal         9980  VARIOS PRODUCTOS VARIOS       34
# freq           69638         7676                     7676     5391
# mean             NaN          NaN                      NaN      NaN
# std              NaN          NaN                      NaN      NaN
# min              NaN          NaN                      NaN      NaN
# 25%              NaN          NaN                      NaN      NaN
# 50%              NaN          NaN                      NaN      NaN
# 75%              NaN          NaN                      NaN      NaN
# max              NaN          NaN                      NaN      NaN
#
#        UNID_MEDIDA  CODIGO_CARGUE               CARGUE  CODIGO_DESCARGUE  \
# count        76287   7.645600e+04                76456      7.645600e+04
# unique           2            NaN                  660               NaN
# top     Kilogramos            NaN  BOGOTA BOGOTA D. C.               NaN
# freq         72056            NaN                 7990               NaN
# mean           NaN   3.631349e+07                  NaN      3.669421e+07
# std            NaN   2.844753e+07                  NaN      2.837013e+07
# min            NaN   5.001000e+06                  NaN      5.001000e+06
# 25%            NaN   1.100100e+07                  NaN      1.100100e+07
# 50%            NaN   2.528600e+07                  NaN      2.528600e+07
# 75%            NaN   6.819000e+07                  NaN      6.808100e+07
# max            NaN   9.977300e+07                  NaN      9.977300e+07
#
#                   DESCARGUE   HORAS_VIAJE  HORAS_ESPERA_CARGUE  HORAS_CARGUE  \
# count                 76453  76456.000000         76456.000000  76456.000000
# unique                 1127           NaN                  NaN           NaN
# top     BOGOTA BOGOTA D. C.           NaN                  NaN           NaN
# freq                   7721           NaN                  NaN           NaN
# mean                    NaN     36.744222             0.498633      2.164576
# std                     NaN     39.879630             1.771776      4.317992
# min                     NaN      0.220000             0.000000     -1.000000
# 25%                     NaN     14.000000             0.000000      0.980000
# 50%                     NaN     24.420000             0.000000      1.000000
# 75%                     NaN     47.000000             0.570000      2.000000
# max                     NaN    696.970000           105.670000    186.770000
#
#         HORAS_ESPERA_DESCARGUE  HORAS_DESCARGUE  VALOR_PACTADO  VALOR_PAGADO  \
# count             76456.000000     76456.000000   7.645600e+04  7.645600e+04
# unique                     NaN              NaN            NaN           NaN
# top                        NaN              NaN            NaN           NaN
# freq                       NaN              NaN            NaN           NaN
# mean                  0.660666         2.342110   1.035159e+06  1.035885e+06
# std                   2.793127         4.480314   1.511995e+06  1.514529e+06
# min                   0.000000         0.000000   0.000000e+00  0.000000e+00
# 25%                   0.000000         0.980000   1.119200e+02  1.119200e+02
# 50%                   0.020000         1.000000   6.600000e+02  6.600000e+02
# 75%                   0.930000         2.000000   1.700000e+06  1.700000e+06
# max                 161.430000       192.250000   3.812000e+07  3.812000e+07
#
#         CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE         PLACA  \
# count             76456.000000        76456.000000  7.645600e+04
# unique                     NaN                 NaN           NaN
# top                        NaN                 NaN           NaN
# freq                       NaN                 NaN           NaN
# mean                  2.585762         2135.402441  4.715577e+05
# std                   4.758924         8058.287322  4.954666e+05
# min                   0.000000            4.000000  3.910000e+02
# 25%                   1.000000          388.000000  1.196862e+05
# 50%                   1.000000         1148.000000  2.470050e+05
# 75%                   1.000000         2144.000000  9.149020e+05
# max                  45.000000        92739.000000  1.491461e+06
#
#             CONDUCTOR
# count    76456.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    168201.388328
# std      66679.992544
# min         41.000000
# 25%     123241.000000
# 50%     151421.500000
# 75%     188460.000000
# max     328918.000000

# %%
nan_count = df.isna().sum()
print(nan_count )
# Out:
# NATURALEZA                169
# COD_PRODUCTO                0
# PRODUCTO                    0
# CANTIDAD                    0
# UNID_MEDIDA               169
# CODIGO_CARGUE               0
# CARGUE                      0
# CODIGO_DESCARGUE            0
# DESCARGUE                   3
# HORAS_VIAJE                 0
# HORAS_ESPERA_CARGUE         0
# HORAS_CARGUE                0
# HORAS_ESPERA_DESCARGUE      0
# HORAS_DESCARGUE             0
# VALOR_PACTADO               0
# VALOR_PAGADO                0
# CANTIDAD_REMESAS_VIAJE      0
# EMPRESA_TRANSPORTE          0
# PLACA                       0
# CONDUCTOR                   0
# dtype: int64

# %%
df.nunique()
# Out:
# NATURALEZA                    6
# COD_PRODUCTO               1004
# PRODUCTO                   1021
# CANTIDAD                  10550
# UNID_MEDIDA                   2
# CODIGO_CARGUE               658
# CARGUE                      660
# CODIGO_DESCARGUE           1126
# DESCARGUE                  1127
# HORAS_VIAJE                6438
# HORAS_ESPERA_CARGUE         604
# HORAS_CARGUE                970
# HORAS_ESPERA_DESCARGUE      749
# HORAS_DESCARGUE            1188
# VALOR_PACTADO             11972
# VALOR_PAGADO              12316
# CANTIDAD_REMESAS_VIAJE       38
# EMPRESA_TRANSPORTE         1409
# PLACA                     40897
# CONDUCTOR                 41525
# dtype: int64

# %%
df1 = df.copy()

# %%
#Valor real qu será usado para predecir
print(df.iloc[[45879]])
# Out:
#             NATURALEZA COD_PRODUCTO  \
# 45879  Carga Peligrosa         1977
#
#                                              PRODUCTO CANTIDAD UNID_MEDIDA  \
# 45879  GASES 1977 -2.2 -NITRÓGENO LÍQUIDO REFRIGERADO     1.78  Kilogramos
#
#        CODIGO_CARGUE                CARGUE  CODIGO_DESCARGUE  \
# 45879       76001000  CALI VALLE DEL CAUCA          76892000
#
#                    DESCARGUE  HORAS_VIAJE  HORAS_ESPERA_CARGUE  HORAS_CARGUE  \
# 45879  YUMBO VALLE DEL CAUCA         18.0                  0.0          0.98
#
#        HORAS_ESPERA_DESCARGUE  HORAS_DESCARGUE  VALOR_PACTADO  VALOR_PAGADO  \
# 45879                     0.0              1.0            0.0           0.0
#
#        CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE   PLACA  CONDUCTOR
# 45879                       7                 173  129743     189504

# %%
#Se eliminan columnas que no aportan al objetivo del análisis
df = df.drop(columns=['PLACA', 'CONDUCTOR', 'UNID_MEDIDA','COD_PRODUCTO','CODIGO_CARGUE', 'CODIGO_DESCARGUE', 'HORAS_ESPERA_CARGUE', 'HORAS_ESPERA_DESCARGUE', 'HORAS_CARGUE','HORAS_DESCARGUE'])

# %%
df.shape
# Out:
# (76456, 10)

# %%
print(df.describe(include='all'))
# Out:
#           NATURALEZA                 PRODUCTO CANTIDAD               CARGUE  \
# count          76287                    76456    76456                76456
# unique             6                     1021    10550                  660
# top     Carga Normal  VARIOS PRODUCTOS VARIOS       34  BOGOTA BOGOTA D. C.
# freq           69638                     7676     5391                 7990
# mean             NaN                      NaN      NaN                  NaN
# std              NaN                      NaN      NaN                  NaN
# min              NaN                      NaN      NaN                  NaN
# 25%              NaN                      NaN      NaN                  NaN
# 50%              NaN                      NaN      NaN                  NaN
# 75%              NaN                      NaN      NaN                  NaN
# max              NaN                      NaN      NaN                  NaN
#
#                   DESCARGUE   HORAS_VIAJE  VALOR_PACTADO  VALOR_PAGADO  \
# count                 76453  76456.000000   7.645600e+04  7.645600e+04
# unique                 1127           NaN            NaN           NaN
# top     BOGOTA BOGOTA D. C.           NaN            NaN           NaN
# freq                   7721           NaN            NaN           NaN
# mean                    NaN     36.744222   1.035159e+06  1.035885e+06
# std                     NaN     39.879630   1.511995e+06  1.514529e+06
# min                     NaN      0.220000   0.000000e+00  0.000000e+00
# 25%                     NaN     14.000000   1.119200e+02  1.119200e+02
# 50%                     NaN     24.420000   6.600000e+02  6.600000e+02
# 75%                     NaN     47.000000   1.700000e+06  1.700000e+06
# max                     NaN    696.970000   3.812000e+07  3.812000e+07
#
#         CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE
# count             76456.000000        76456.000000
# unique                     NaN                 NaN
# top                        NaN                 NaN
# freq                       NaN                 NaN
# mean                  2.585762         2135.402441
# std                   4.758924         8058.287322
# min                   0.000000            4.000000
# 25%                   1.000000          388.000000
# 50%                   1.000000         1148.000000
# 75%                   1.000000         2144.000000
# max                  45.000000        92739.000000

# %%
# Traduce los valores categóricos de NATURALEZA, PRODUCTO, CARGUE, DESCARGUE Y CANTIDAD DE REMESAS a números enteros
df['NATURALEZA'] = df['NATURALEZA'].astype('category').cat.codes #one hot encoding
df['PRODUCTO'] = df['PRODUCTO'].astype('category').cat.codes
df['CARGUE'] = df['CARGUE'].astype('category').cat.codes
df['DESCARGUE'] = df['DESCARGUE'].astype('category').cat.codes
df['CANTIDAD'] = df['CANTIDAD'].astype('category').cat.codes
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD  CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0           1       570      6235     211       1097        14.97
# 1           1       570      6525     211        118        22.13
# 2           1       570      7813     259        213        15.13
# 3           1       570      4957     110        229        27.47
# 4           1       570      6412     211        118        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE
# 0            0.0           0.0                       1                 335
# 1            0.0           0.0                       1                 335
# 2            0.0           0.0                       1                 335
# 3      2090424.0     2090424.0                       1                 335
# 4            0.0           0.0                       1                 335

# %%
#Convertir variables object a enteros
df['CANTIDAD'] = df['CANTIDAD'].astype(float)
df['CANTIDAD_REMESAS_VIAJE'] = df['CANTIDAD_REMESAS_VIAJE'].astype(float)

# %%
df.dtypes
# Out:
# NATURALEZA                   int8
# PRODUCTO                    int16
# CANTIDAD                  float64
# CARGUE                      int16
# DESCARGUE                   int16
# HORAS_VIAJE               float64
# VALOR_PACTADO             float64
# VALOR_PAGADO              float64
# CANTIDAD_REMESAS_VIAJE    float64
# EMPRESA_TRANSPORTE          int64
# dtype: object

# %%
#Convertir la variable HORAS_VIAJE en SEGUNDOS_VIAJE
def separar_float(HORAS_VIAJE):
    parte_entera = int(HORAS_VIAJE)
    parte_decimal = HORAS_VIAJE - parte_entera
    Horas_seg = parte_entera * 3600
    Min_seg = parte_decimal * 360
    SEGUNDOS_VIAJE =  Horas_seg + Min_seg
    return SEGUNDOS_VIAJE

# Aplicar la función al DataFrame para obtener las dos partes separadas
df[['SEGUNDOS_VIAJE']] = df['HORAS_VIAJE'].apply(lambda x: pd.Series(separar_float(x)))
# %time
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs

# %%
print(df.describe(include='all'))
# Out:
#          NATURALEZA      PRODUCTO      CANTIDAD        CARGUE     DESCARGUE  \
# count  76456.000000  76456.000000  76456.000000  76456.000000  76456.000000
# mean       1.118212    531.786531   5379.438331    263.745017    467.639714
# std        0.474992    311.068347   2795.377496    196.376398    338.823043
# min       -1.000000      0.000000      0.000000      0.000000     -1.000000
# 25%        1.000000    287.750000   2928.000000     79.000000    130.000000
# 50%        1.000000    570.000000   5988.000000    211.000000    402.000000
# 75%        1.000000    772.000000   7584.000000    392.000000    701.000000
# max        5.000000   1020.000000  10549.000000    659.000000   1126.000000
#
#         HORAS_VIAJE  VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  \
# count  76456.000000   7.645600e+04  7.645600e+04            76456.000000
# mean      36.744222   1.035159e+06  1.035885e+06                2.585762
# std       39.879630   1.511995e+06  1.514529e+06                4.758924
# min        0.220000   0.000000e+00  0.000000e+00                0.000000
# 25%       14.000000   1.119200e+02  1.119200e+02                1.000000
# 50%       24.420000   6.600000e+02  6.600000e+02                1.000000
# 75%       47.000000   1.700000e+06  1.700000e+06                1.000000
# max      696.970000   3.812000e+07  3.812000e+07               45.000000
#
#        EMPRESA_TRANSPORTE  SEGUNDOS_VIAJE
# count        76456.000000    7.645600e+04
# mean          2135.402441    1.314040e+05
# std           8058.287322    1.435070e+05
# min              4.000000    7.920000e+01
# 25%            388.000000    5.040000e+04
# 50%           1148.000000    8.655120e+04
# 75%           2144.000000    1.692000e+05
# max          92739.000000    2.505949e+06

# %%
df.dtypes
# Out:
# NATURALEZA                   int8
# PRODUCTO                    int16
# CANTIDAD                  float64
# CARGUE                      int16
# DESCARGUE                   int16
# HORAS_VIAJE               float64
# VALOR_PACTADO             float64
# VALOR_PAGADO              float64
# CANTIDAD_REMESAS_VIAJE    float64
# EMPRESA_TRANSPORTE          int64
# SEGUNDOS_VIAJE            float64
# dtype: object

# %%
nan_count = df.isna().sum()
print(nan_count )
# Out:
# NATURALEZA                0
# PRODUCTO                  0
# CANTIDAD                  0
# CARGUE                    0
# DESCARGUE                 0
# HORAS_VIAJE               0
# VALOR_PACTADO             0
# VALOR_PAGADO              0
# CANTIDAD_REMESAS_VIAJE    0
# EMPRESA_TRANSPORTE        0
# SEGUNDOS_VIAJE            0
# dtype: int64

# %%
# HISTOGRAMA DE NATURALEZA DE LA CARGA
df['NATURALEZA'].hist(bins=10, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('NATURALEZA DE LA CARGA')

# Muestra el histograma
plt.show()

# %%
# HISTOGRAMA DE MUNICIPIO DE CARGUE
df['CARGUE'].hist(bins=10, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('MUNICIPIO DE CARGUE')

# Muestra el histograma
plt.show()

# %%
# HISTOGRAMA DE MUNICIPIO DE DESCARGUE
df['DESCARGUE'].hist(bins=10, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('MUNICIPIO DE DESCARGUE')

# Muestra el histograma
plt.show()

# %%
# HISTOGRAMA DE PRODUCTO TRANSPORTADO
df['PRODUCTO'].hist(bins=10, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('PRODUCTO TRANSPORTADO')

# Muestra el histograma
plt.show()

# %%
# HISTOGRAMA DE CANTIDAD DE PRODUCTO TRANSPORTADO
df['CANTIDAD'].hist(bins=10, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('CANTIDAD DE PRODUCTO TRANSPORTADO')

# Muestra el histograma
plt.show()

# %%
# HISTOGRAMA DE VALOR PAGADO
df['VALOR_PAGADO'].hist(bins=10, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('VALOR PAGADO')

# Muestra el histograma
plt.show()

# %%
# HISTOGRAMA DE SEGUNDOS_VIAJE
df['SEGUNDOS_VIAJE'].hist(bins=5, edgecolor='black')

# Agrega etiquetas a los ejes x e y y un título al gráfico
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.title('TIEMPO DE VIAJE (en segundos)')

# Muestra el histograma
plt.show()

# %%
df2 = df.copy() #ya tengo los datos procesados y listos para arrancar
df2.to_csv('Transporte_Logistico.csv')
df2.head(3)
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD  CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0           1       570    6235.0     211       1097        14.97
# 1           1       570    6525.0     211        118        22.13
# 2           1       570    7813.0     259        213        15.13
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0           0.0                     1.0                 335
# 1            0.0           0.0                     1.0                 335
# 2            0.0           0.0                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8

# %%
df.dtypes
# Out:
# NATURALEZA                   int8
# PRODUCTO                    int16
# CANTIDAD                  float64
# CARGUE                      int16
# DESCARGUE                   int16
# HORAS_VIAJE               float64
# VALOR_PACTADO             float64
# VALOR_PAGADO              float64
# CANTIDAD_REMESAS_VIAJE    float64
# EMPRESA_TRANSPORTE          int64
# SEGUNDOS_VIAJE            float64
# dtype: object

# %%
# Escalamiento de los datos
X = df[['NATURALEZA', 'PRODUCTO','CANTIDAD','CARGUE','DESCARGUE','SEGUNDOS_VIAJE']].values
y = df['VALOR_PAGADO'].values.reshape(-1, 1)

sc_x = StandardScaler() #Crear una instancia
sc_y = StandardScaler()

X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y)
print(X_std)
# Out:
# [[-0.24887256  0.1228467   0.30606502 -0.26859318  1.85750177 -0.56203082]
#  [-0.24887256  0.1228467   0.40980839 -0.26859318 -1.031931   -0.36344962]
#  [-0.24887256  0.1228467   0.87057207 -0.02416302 -0.75154682 -0.53905199]
#  ...
#  [-0.24887256  0.52790502 -1.37421993  1.62574054 -1.1027649   0.28846165]
#  [-0.24887256  0.52790502 -1.38817162  1.51371005 -0.6039762   0.33863376]
#  [-0.24887256  0.52790502 -1.34238144 -0.55885399 -0.99651405 -0.36377574]]

# %%
plt.scatter(X,y)

# %%
#Normalizar los datos
df['NATURALEZA'] = sc_x.fit_transform(df[['NATURALEZA']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD  CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873       570    6235.0     211       1097        14.97
# 1   -0.248873       570    6525.0     211        118        22.13
# 2   -0.248873       570    7813.0     259        213        15.13
# 3   -0.248873       570    4957.0     110        229        27.47
# 4   -0.248873       570    6412.0     211        118        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0           0.0                     1.0                 335
# 1            0.0           0.0                     1.0                 335
# 2            0.0           0.0                     1.0                 335
# 3      2090424.0     2090424.0                     1.0                 335
# 4            0.0           0.0                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8
# 3         97369.2
# 4         83026.8

# %%
df['VALOR_PAGADO'] = sc_x.fit_transform(df[['VALOR_PAGADO']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD  CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873       570    6235.0     211       1097        14.97
# 1   -0.248873       570    6525.0     211        118        22.13
# 2   -0.248873       570    7813.0     259        213        15.13
# 3   -0.248873       570    4957.0     110        229        27.47
# 4   -0.248873       570    6412.0     211        118        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8
# 3         97369.2
# 4         83026.8

# %%
df['CARGUE'] = sc_x.fit_transform(df[['CARGUE']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873       570    6235.0 -0.268593       1097        14.97
# 1   -0.248873       570    6525.0 -0.268593        118        22.13
# 2   -0.248873       570    7813.0 -0.024163        213        15.13
# 3   -0.248873       570    4957.0 -0.782915        229        27.47
# 4   -0.248873       570    6412.0 -0.268593        118        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8
# 3         97369.2
# 4         83026.8

# %%
df['DESCARGUE'] = sc_x.fit_transform(df[['DESCARGUE']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873       570    6235.0 -0.268593   1.857502        14.97
# 1   -0.248873       570    6525.0 -0.268593  -1.031931        22.13
# 2   -0.248873       570    7813.0 -0.024163  -0.751547        15.13
# 3   -0.248873       570    4957.0 -0.782915  -0.704324        27.47
# 4   -0.248873       570    6412.0 -0.268593  -1.031931        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8
# 3         97369.2
# 4         83026.8

# %%
df['PRODUCTO'] = sc_x.fit_transform(df[['PRODUCTO']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873  0.122847    6235.0 -0.268593   1.857502        14.97
# 1   -0.248873  0.122847    6525.0 -0.268593  -1.031931        22.13
# 2   -0.248873  0.122847    7813.0 -0.024163  -0.751547        15.13
# 3   -0.248873  0.122847    4957.0 -0.782915  -0.704324        27.47
# 4   -0.248873  0.122847    6412.0 -0.268593  -1.031931        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8
# 3         97369.2
# 4         83026.8

# %%
df['CANTIDAD'] = sc_x.fit_transform(df[['CANTIDAD']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873  0.122847  0.306065 -0.268593   1.857502        14.97
# 1   -0.248873  0.122847  0.409808 -0.268593  -1.031931        22.13
# 2   -0.248873  0.122847  0.870572 -0.024163  -0.751547        15.13
# 3   -0.248873  0.122847 -0.151121 -0.782915  -0.704324        27.47
# 4   -0.248873  0.122847  0.369384 -0.268593  -1.031931        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0         50749.2
# 1         79246.8
# 2         54046.8
# 3         97369.2
# 4         83026.8

# %%
df['SEGUNDOS_VIAJE'] = sc_x.fit_transform(df[['CANTIDAD']])
df.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873  0.122847  0.306065 -0.268593   1.857502        14.97
# 1   -0.248873  0.122847  0.409808 -0.268593  -1.031931        22.13
# 2   -0.248873  0.122847  0.870572 -0.024163  -0.751547        15.13
# 3   -0.248873  0.122847 -0.151121 -0.782915  -0.704324        27.47
# 4   -0.248873  0.122847  0.369384 -0.268593  -1.031931        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE
# 0        0.306065
# 1        0.409808
# 2        0.870572
# 3       -0.151121
# 4        0.369384

# %% [markdown]
# ####**MATRIZ DE CORRELACIÓN**

# %%
matriz_correlacion = df.corr()

print("Matriz de correlación:")
print(matriz_correlacion)
# Out:
# Matriz de correlación:
#                         NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  \
# NATURALEZA                1.000000 -0.120326  0.055903  0.012006   0.040780
# PRODUCTO                 -0.120326  1.000000 -0.093335 -0.060538   0.009968
# CANTIDAD                  0.055903 -0.093335  1.000000  0.004282  -0.002240
# CARGUE                    0.012006 -0.060538  0.004282  1.000000  -0.043123
# DESCARGUE                 0.040780  0.009968 -0.002240 -0.043123   1.000000
# HORAS_VIAJE              -0.053164  0.064178 -0.010057 -0.049482  -0.026931
# VALOR_PACTADO             0.007773 -0.110697  0.050319 -0.020207  -0.062543
# VALOR_PAGADO              0.008178 -0.110668  0.050630 -0.019781  -0.062721
# CANTIDAD_REMESAS_VIAJE   -0.062382  0.103938 -0.118058 -0.085284   0.004768
# EMPRESA_TRANSPORTE        0.005570 -0.031906 -0.001826  0.017941   0.012409
# SEGUNDOS_VIAJE            0.055903 -0.093335  1.000000  0.004282  -0.002240
#
#                         HORAS_VIAJE  VALOR_PACTADO  VALOR_PAGADO  \
# NATURALEZA                -0.053164       0.007773      0.008178
# PRODUCTO                   0.064178      -0.110697     -0.110668
# CANTIDAD                  -0.010057       0.050319      0.050630
# CARGUE                    -0.049482      -0.020207     -0.019781
# DESCARGUE                 -0.026931      -0.062543     -0.062721
# HORAS_VIAJE                1.000000       0.215153      0.214476
# VALOR_PACTADO              0.215153       1.000000      0.998081
# VALOR_PAGADO               0.214476       0.998081      1.000000
# CANTIDAD_REMESAS_VIAJE     0.152616      -0.048759     -0.048853
# EMPRESA_TRANSPORTE         0.004498      -0.000334     -0.000532
# SEGUNDOS_VIAJE            -0.010057       0.050319      0.050630
#
#                         CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# NATURALEZA                           -0.062382            0.005570
# PRODUCTO                              0.103938           -0.031906
# CANTIDAD                             -0.118058           -0.001826
# CARGUE                               -0.085284            0.017941
# DESCARGUE                             0.004768            0.012409
# HORAS_VIAJE                           0.152616            0.004498
# VALOR_PACTADO                        -0.048759           -0.000334
# VALOR_PAGADO                         -0.048853           -0.000532
# CANTIDAD_REMESAS_VIAJE                1.000000           -0.014584
# EMPRESA_TRANSPORTE                   -0.014584            1.000000
# SEGUNDOS_VIAJE                       -0.118058           -0.001826
#
#                         SEGUNDOS_VIAJE
# NATURALEZA                    0.055903
# PRODUCTO                     -0.093335
# CANTIDAD                      1.000000
# CARGUE                        0.004282
# DESCARGUE                    -0.002240
# HORAS_VIAJE                  -0.010057
# VALOR_PACTADO                 0.050319
# VALOR_PAGADO                  0.050630
# CANTIDAD_REMESAS_VIAJE       -0.118058
# EMPRESA_TRANSPORTE           -0.001826
# SEGUNDOS_VIAJE                1.000000

# %%
#Exportemos los datos para disponer de ellos mas adelante.
df3 = df.copy() #ya tengo los datos procesados y listos para arrancar
df3.to_csv('Variables_escaladas_normalizadas.csv')

# %%
#Separación de los datos
#Variables --> 'NATURALEZA','CARGUE','DESCARGUE','PRODUCTO','CANTIDAD'
X = df[['SEGUNDOS_VIAJE']]
y = df[['VALOR_PAGADO']]
original = X.copy()
print(X, y)
# Out:
#        SEGUNDOS_VIAJE
# 0            0.306065
# 1            0.409808
# 2            0.870572
# 3           -0.151121
# 4            0.369384
# ...               ...
# 76451       -1.432531
# 76452       -1.579203
# 76453       -1.374220
# 76454       -1.388172
# 76455       -1.342381
#
# [76456 rows x 1 columns]        VALOR_PAGADO
# 0         -0.683970
# 1         -0.683970
# 2         -0.683970
# 3          0.696286
# 4         -0.683970
# ...             ...
# 76451      1.082796
# 76452      0.240416
# 76453      1.867335
# 76454      1.111980
# 76455      1.127694
#
# [76456 rows x 1 columns]

# %%
plt.scatter(X,y)

# %%
print(df.describe(include='all'))
# Out:
#          NATURALEZA      PRODUCTO      CANTIDAD        CARGUE     DESCARGUE  \
# count  7.645600e+04  7.645600e+04  7.645600e+04  7.645600e+04  7.645600e+04
# mean  -2.304784e-17 -3.568698e-17  2.379132e-17  5.947831e-17 -2.304784e-17
# std    1.000007e+00  1.000007e+00  1.000007e+00  1.000007e+00  1.000007e+00
# min   -4.459494e+00 -1.709560e+00 -1.924418e+00 -1.343067e+00 -1.383149e+00
# 25%   -2.488726e-01 -7.845161e-01 -8.769672e-01 -9.407761e-01 -9.965140e-01
# 50%   -2.488726e-01  1.228467e-01  2.177043e-01 -2.685932e-01 -1.937299e-01
# 75%   -2.488726e-01  7.722259e-01  7.886506e-01  6.531122e-01  6.887424e-01
# max    8.172371e+00  1.569484e+00  1.849337e+00  2.012755e+00  1.943093e+00
#
#         HORAS_VIAJE  VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  \
# count  76456.000000   7.645600e+04  7.645600e+04            76456.000000
# mean      36.744222   1.035159e+06  7.955224e-17                2.585762
# std       39.879630   1.511995e+06  1.000007e+00                4.758924
# min        0.220000   0.000000e+00 -6.839699e-01                0.000000
# 25%       14.000000   1.119200e+02 -6.838960e-01                1.000000
# 50%       24.420000   6.600000e+02 -6.835341e-01                1.000000
# 75%       47.000000   1.700000e+06  4.384987e-01                1.000000
# max      696.970000   3.812000e+07  2.448574e+01               45.000000
#
#        EMPRESA_TRANSPORTE  SEGUNDOS_VIAJE
# count        76456.000000    7.645600e+04
# mean          2135.402441   -2.379132e-17
# std           8058.287322    1.000007e+00
# min              4.000000   -1.924418e+00
# 25%            388.000000   -8.769672e-01
# 50%           1148.000000    2.177043e-01
# 75%           2144.000000    7.886506e-01
# max          92739.000000    1.849337e+00

# %% [markdown]
# ####**DIVIDIR LOS DATOS EN ENTRENAMIENTO Y PRUEBA**`

# %%
#train_test_split, parte automticamente los valores entregando x e y definiendo el 20% testsize y el random state = 3 para repetir el modelo.
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=3)
print(type(X_test))
print(type(y_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#Se detalla el tamaño de ambos conjuntos de entrenamiento y de prueba
X.shape,y.shape
# Out:
# ((76456, 1), (76456, 1))

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((61164, 1), (15292, 1), (61164, 1), (15292, 1))

# %% [markdown]
# ##**CREAR EL MODELO DE CLASIFICACIÓN**
# ###**K-MEDIAS-MÉTODO DE CLUSTERING**

# %%
from sklearn.cluster import KMeans
df4 = df.copy()
plt.figure(figsize=(10, 10))
plt.scatter(df['VALOR_PAGADO'], df['SEGUNDOS_VIAJE'])
plt.axis('equal')
plt.show()

# %%
df.dtypes
# Out:
# NATURALEZA                float64
# PRODUCTO                  float64
# CANTIDAD                  float64
# CARGUE                    float64
# DESCARGUE                 float64
# HORAS_VIAJE               float64
# VALOR_PACTADO             float64
# VALOR_PAGADO              float64
# CANTIDAD_REMESAS_VIAJE    float64
# EMPRESA_TRANSPORTE          int64
# SEGUNDOS_VIAJE            float64
# dtype: object

# %%
#Se eliminan columnas que no aportan al objetivo del análisis
#Creamos un dataframe con variables de interés
h = df.drop(columns=['NATURALEZA', 'PRODUCTO', 'CANTIDAD','CARGUE','DESCARGUE', 'HORAS_VIAJE', 'VALOR_PACTADO','CANTIDAD_REMESAS_VIAJE','EMPRESA_TRANSPORTE'])

# %%
h.dtypes
# Out:
# VALOR_PAGADO      float64
# SEGUNDOS_VIAJE    float64
# dtype: object

# %%
distortions = []
K = range(1,11)
for k in K: #El modelo se ejecuta 20 veces guardando los valores de distorsion en distorsions
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(h)
    distortions.append(kmeanModel.inertia_)
    # %time
# Out:
# CPU times: user 7 µs, sys: 2 µs, total: 9 µs
# Wall time: 8.11 µs
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 7.39 µs
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.63 µs
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 6.91 µs
# CPU times: user 8 µs, sys: 2 µs, total: 10 µs
# Wall time: 7.87 µs
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.68 µs
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs

# %%
plt.figure(figsize=(10,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distorsion')
plt.title('El metodo del codo pinta el k optimo')
plt.show()

# %%
kmeans = KMeans(3)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
gruposIdentificados = kmeans.fit_predict(h) #aca no tengo train y test, no tengo el valor final, aca no tengo y
gruposIdentificados
# Out:
# array([2, 2, 2, ..., 1, 0, 0], dtype=int32)

# %%
datosAGrupados = df.copy()
datosAGrupados['Cluster'] = gruposIdentificados
datosAGrupados.to_excel('DAtosAgrupados.xlsx')
# %time
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.34 µs

# %%
datosAGrupados.head()
# Out:
#    NATURALEZA  PRODUCTO  CANTIDAD    CARGUE  DESCARGUE  HORAS_VIAJE  \
# 0   -0.248873  0.122847  0.306065 -0.268593   1.857502        14.97
# 1   -0.248873  0.122847  0.409808 -0.268593  -1.031931        22.13
# 2   -0.248873  0.122847  0.870572 -0.024163  -0.751547        15.13
# 3   -0.248873  0.122847 -0.151121 -0.782915  -0.704324        27.47
# 4   -0.248873  0.122847  0.369384 -0.268593  -1.031931        23.63
#
#    VALOR_PACTADO  VALOR_PAGADO  CANTIDAD_REMESAS_VIAJE  EMPRESA_TRANSPORTE  \
# 0            0.0     -0.683970                     1.0                 335
# 1            0.0     -0.683970                     1.0                 335
# 2            0.0     -0.683970                     1.0                 335
# 3      2090424.0      0.696286                     1.0                 335
# 4            0.0     -0.683970                     1.0                 335
#
#    SEGUNDOS_VIAJE  Cluster
# 0        0.306065        2
# 1        0.409808        2
# 2        0.870572        2
# 3       -0.151121        1
# 4        0.369384        2

# %%
plt.figure(figsize=(15, 15))
plt.scatter(datosAGrupados['VALOR_PAGADO'],
            datosAGrupados['SEGUNDOS_VIAJE'],
            c=datosAGrupados['Cluster'],
            cmap='rainbow')
plt.grid(axis= 'both', color='b', alpha=0.5)
plt.axis('equal')
plt.show()

# %% [markdown]
# ####**RESPUESTAS RUTA METODOLÓGICA**
#
# **Después de analizar la información extraída y transformada, responde a las siguientes preguntas:**
#
# <br>**¿El valor o dato a predecir está bien seleccionado?**</br>
#
#
# <br>**¿El Score o métricas del modelo se ajustan a la realidad?**</br>
#
#
#
# <br>**¿Los tiempos de predicción son cortos, medianos, largos?**</br>
#
#
# </br>**¿Qué observaciones tienes del modelo y de sus resultados?**</br>

# %% [markdown]
# ###**CONCLUSIONES**
#
# Se consigue generar un modelo de clasificación de los datos a través de la prueba k-medias y la identificaicón de las distorsiones.
#
# Se reconocen los grupos clasificados en este caso se genera 3 cluster, basados en el gráfico de codo, pues en este punto (3) no se evidencian cambios significativos.
#
# Se crea la nueva variable en el conjunto de datos que establece el grupo al cual pertenece cada registro.
#
# Es un ejercicio muiy valioso que nos permitió aprender mucho y aplicar el conocimiento adquirido.
